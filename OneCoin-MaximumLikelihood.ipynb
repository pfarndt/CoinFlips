# %%
using Distributions
using PyPlot

# %%
function prob(observed_data, model_parameter)
    n1 = observed_data[1]
    n2 = observed_data[2]
    N = n1 + n2
    
    p = model_parameter[1]
    
    return pdf(Binomial(N, p), n1)
#     return binomial(N, n1) * p^n1 * (1-p)^n2
end
# Out:
# prob (generic function with 1 method)

# %%
x = 0 : 0.001 : 1

# observed_data = [0,1]
# y= [prob(observed_data, [xi]) for xi in x];
# plot(x, y, label = string(observed_data))


# observed_data = [2,2]
# y= [prob(observed_data, [xi]) for xi in x];
# plot(x, y, label = string(observed_data))

# observed_data = [1, 3]
# y= [ prob(observed_data, [xi])  for xi in x];
# plot(x, y, label = string(observed_data))

observed_data = [141, 75] 
y= [prob(observed_data, [xi]) for xi in x];
plot(x, y, label = string(observed_data))

observed_data = [167, 63]
y= [prob(observed_data, [xi]) for xi in x];
plot(x, y, label = string(observed_data))

observed_data = [136, 80]
y= [prob(observed_data, [xi]) for xi in x];
plot(x, y, label = string(observed_data))

observed_data = [136+167, 80+63]
y= [prob(observed_data, [xi]) for xi in x];
plot(x, y, label = string(observed_data))



ylabel("Likelihood")
xlabel("p")
# yscale("log")
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x7f8bddb7c1d0>

# %%
using Optim

# %%
observed_data = [91,110]
# Out:
# 2-element Array{Int64,1}:
#   91
#  110

# %%
optimize(func, [0.1])

# %%
res = optimize(p -> -prob(observed_data, p ), [0.5], Newton())
# Out:
#  * Status: success
#
#  * Candidate solution
#     Minimizer: [4.53e-01]
#     Minimum:   -5.646046e-02
#
#  * Found with
#     Algorithm:     Newton's Method
#     Initial Point: [5.00e-01]
#
#  * Convergence measures
#     |x - x'|               = 4.12e-05 ≰ 0.0e+00
#     |x - x'|/|x'|          = 9.10e-05 ≰ 0.0e+00
#     |f(x) - f(x')|         = 3.89e-08 ≰ 0.0e+00
#     |f(x) - f(x')|/|f(x')| = 6.89e-07 ≰ 0.0e+00
#     |g(x)|                 = 0.00e+00 ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    3
#     f(x) calls:    7
#     ∇f(x) calls:   7
#     ∇²f(x) calls:  3

# %%
Optim.minimizer(res)
# Out:
# 1-element Array{Float64,1}:
#  0.45273631841262263

# %%
observed_data[1] / (observed_data[1] + observed_data[2])
# Out:
# 0.4527363184079602

# %%
Optim.minimizer(res)[1]  == observed_data[1] / (observed_data[1] + observed_data[2])
# Out:
# false

# %%
Optim.minimizer(res)[1] ≈ observed_data[1] / (observed_data[1] + observed_data[2])
# Out:
# true
